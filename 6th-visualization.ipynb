# %%
# 데이터 분석에 필요한 기본적인 라이브러리
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 시각화 라이브러리
import seaborn as sns

# %% [markdown]
# # BarPlot
#
# - 범주형 자료의 갯수를 세어 막대로 나타내는 기법.
# - 자료의 크기 정도를 높이로 요약하여 준다.
# - 졸리다.

# %%
x = ['A group', 'B group']
y = [12, 6]

# %%
plt.bar(x, y)
plt.title('bar plot test')
plt.xlabel('category')
plt.ylabel('count')
plt.show()

# %%
# plt의 barplot은 자료를 직접 만들어줘야 한다.

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 요일별 식당을 방문한 팀의 수는?

day_value = tips['day'].value_counts()
day_label = tips['day'].unique()

plt.bar(day_label, day_value)
plt.title('Day count', fontsize = 20)
plt.xlabel('day')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
# DataFrame을 이용한 막대그래프 그리기

pd.DataFrame(day_value).plot(kind = 'bar', y = 'day')
plt.xticks(rotation = -30) # xlabel을 회전시킨다.
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %%
# seaborn의 barplot
# x, y를 직접 입력 가능
# x를 기준으로 정렬하여 barplot을 그려준다

sns.barplot(x = day_label, y = day_value)
plt.title('day count', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'day count')

# %%
# column 이름과 데이터셋으로 입력하면 안되나?
# 요일별 팁의 barplot?

sns.barplot(x = 'day', y = 'tip', data = tips)

# %%
# countplot

sns.countplot(x = 'day', data = tips)
plt.title('day count', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'day count')

# %%
# seaborn의 palette 기능
# 다양한 색깔을 활용하여 그라데이션 효과를 적용

# saturation : 채도를 조절

sns.countplot(x = 'day', data = tips,
              palette = 'rocket', saturation = 0.2)
plt.title('day count', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'day count')

# %%
sns.countplot(x = 'day', hue = 'size', data = tips,
              palette = 'rocket', saturation = 0.6)
plt.title('day count with people size')
plt.show()

# %%
# 분석 결과 : 주말에 단체손님이 많음.
# 주로 2인씩 방문함

# %%
# plot 여러개를 한꺼번에 그리기
# subplot이라고 한다.

# 먼저 도화지의 모양을 설정해줘야 한다.

fig, ax = plt.subplots(1, 3, figsize = (21, 7))
fig.suptitle('day countplot', fontsize = 20)

# 각 변수에 시각화 데이터를 저장
c1 = sns.countplot(x = 'day', data = tips,
                   palette = 'rocket', hue = 'sex', ax = ax[0])
c2 = sns.countplot(x = 'day', data = tips,
                   palette = 'pastel', hue = 'size', ax = ax[1])
c3 = sns.countplot(x = 'day', data = tips,
                   palette = 'mako', hue = 'smoker', ax = ax[2])

# 각 시각화 데이터의 제목을 설정하여 지정한 위치(ax)에 출력
c1.set(title = 'day count : sex')
c2.set(title = 'day count : size')
c3.set(title = 'day count : smoker')

plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
c1 = sns.countplot(x = 'day', data = tips,
                   palette = 'rocket', hue = 'time')

# %%
tips[tips['day']=='Thur']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 77        27.20  4.00    Male     No  Thur   Lunch     4
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [62 rows x 7 columns]

# %%
fig, ax = plt.subplots(2, 2, figsize = (10, 10))


c2 = sns.countplot(x = 'size', data = tips[tips['day']=='Thur'],
                   palette = 'pastel', hue = 'time', ax = ax[0,0])
c3 = sns.countplot(x = 'size', data = tips[tips['day']=='Fri'],
                   palette = 'mako', hue = 'time', ax = ax[0,1])
c4 = sns.countplot(x = 'size', data = tips[tips['day']=='Sat'],
                   palette = 'rocket', hue = 'time', ax = ax[1,0])
c5 = sns.countplot(x = 'size', data = tips[tips['day']=='Sun'],
                   palette = 'pastel', hue = 'time', ax = ax[1,1])

c2.set(title = 'day count : Thur')
c3.set(title = 'day count : Fri')
c4.set(title = 'day count : Sat')
c5.set(title = 'day count : Sun')
# Out:
# [Text(0.5, 1.0, 'day count : Sun')]

# %%
# 주말 저녁

# %%
# pie chart

label = ['carbonhydate', 'protein', 'fat']
pie_data = [280, 300, 150]

# autopct : 부채꼴 안에 표시할 숫자 형식
# i : integer, f : fraction, e : exponential
plt.pie(x = pie_data, labels = label, autopct = '%1.3f%%')
plt.title('food pie chart', fontsize = 15)
plt.show()

# %%
# 요일별 식당 방문 팀의 비율?

day_label = tips['day'].unique()
day_ratio = tips['day'].value_counts()

plt.title('Day ratio', fontsize = 15)
plt.pie(x = day_ratio, labels = day_label, autopct = '%1.2f%%')
plt.show()

# %%
# 각도 조절 및 사이 간격, 그림자 설정

plt.pie(day_ratio, labels = day_label, 
        autopct = '%1.2f%%', 
        startangle = 130, explode = [0.1, 0.2, 0.1, 0.05], shadow = True)
plt.show()

# %%
# 커스터마이징

# explode : 각 파이마다 중심으로부터 떨어질 거리를 설정
# colors : 색깔 변경. RGB값은 각각 0-255 설정을 해줘야 한다.
# color은 16진수로 0~ff 까지 입력
# wedfeprops : 파이의 테두리 두께, 색깔등을 설정, dict 형색으로 입력

explode = [0.08, 0, 0.03, 0.03]
colors = ['#ff9933', '#fc392a', '#8dc34f', '#dd9200']
wedgeprops = {'width' : 0.7, 'edgecolor' : 'w', 'linewidth' : 5}

plt.pie(day_ratio, labels = day_label,
        autopct = '%1.2f%%', startangle = 30,
        explode = explode, colors = colors, wedgeprops = wedgeprops,
        shadow = True)
plt.title('day pie chart')
plt.show()

# %%
titanic = sns.load_dataset('titanic')

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
survived_label = ['dead', 'survived']
survived_ratio = titanic['survived'].value_counts()

# %%
explode = [0.08, 0]
colors = ['#009933', '#dd9200']
wedgeprops = {'width' : 0.7, 'edgecolor' : 'w', 'linewidth' : 5}

plt.pie(survived_ratio, labels = survived_label,
        autopct = '%1.2f%%', startangle = 30,
        explode = explode, colors = colors, wedgeprops = wedgeprops,
        shadow = True)
plt.show()

# %%
# hist : 히스토그램 그리기

plt.hist(tips['total_bill'], bins = 8, 
         color = 'r', edgecolor = 'k')
plt.title('total bill histogram')
plt.xlabel('Amount of bill')
plt.ylabel('The number of team')
plt.show()

# %%
# seaborn의 distplot
# 히스토그램 + 분포

sns.distplot(tips['total_bill'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 오늘 분명 일찍 끝내주신다고 하셨잖아요....

# %%
# 특정 통계값을 라인으로 추가해서 보여주기

total_mean = tips['total_bill'].mean()
total_median = np.median(tips['total_bill'])
total_mode = tips['total_bill'].mode()

sns.distplot(tips['total_bill'])

plt.axvline(total_mean, color = 'r', label = 'mean')
plt.axvline(total_median, color = 'b', label = 'median')
plt.axvline(total_mode[0], color = 'g', label = 'mode')

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# mode < median < mean
# 이 식당을 방문한 사람들은 주로 낮은 가격으로 식사를 하는 편.
# 평균을 누군가 끌어올렸ㄴㅔ,,

# %%
# pairplot
# 쌍관계 그래프, 변수간의 상관성을 시각화.

sns.pairplot(tips, palette = 'deep')
plt.show()

# %%
# hue를 이용하여 분리 가능
# marker를 이용하여 데이터를 각각 다른 모양으로 표시 가능
# corner로 중복을 제거

sns.pairplot(tips, hue = 'sex',
             markers = ['o', 'D'], height = 2, corner = True)

plt.show()

# %%
# jointplot

# joint = sns.jointplot(data = tips, x = 'total_bill', y = 'tip',
#                       kind = 'hex')
#joint = sns.jointplot(data = tips, x = 'total_bill', y = 'tip',
#                      kind = 'kde')
joint = sns.jointplot(data = tips, x = 'total_bill', y = 'tip',
                      kind = 'reg')
joint.set_axis_labels(xlabel = 'total_bill', ylabel = 'tip')
joint.fig.suptitle('Joint plot of tip and total bill', fontsize = 20)
plt.show()
